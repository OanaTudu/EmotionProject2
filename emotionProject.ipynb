# %% [markdown]
# ## Emotion Recognition Project
#
# 2019 - OT.
#
# Given the Karolinska faces collection, train a classifier to predict emotion.
# Details about the data (KDEF):
# 70 subjects (35 male, 35 female), all white, between 20 and 30 years of age, photographed with 7 emotion expressions:
# neutral, happy, angry, afraid, disgusted, sad, surprised
#
# Files stored in KDEF folder. Image naming code:
# Codes:
# 	Example: AF01ANFL.JPG
# 		Letter 1: Session
# 					A = series one
# 					B = series two
# 		Letter 2: Gender
# 					F = female
# 					M = male
# 		Letter 3 & 4: Identity number
# 					01 - 35
# 		Letter 5 & 6: Expression
# 					AF = afraid
# 					AN = angry
# 					DI = disgusted
# 					HA = happy
# 					NE = neutral
# 					SA = sad
# 					SU = surprised
# 		Letter 7 & 8: Angle
# 					FL = full left profile
# 					HL = half left profile
# 					S = straight
# 					HR = half right profile
# 					FR = full right profile

# %%
from keras.preprocessing.image import load_img
# load the image
img = load_img('AF01HAS.jpg')
# report details about the image
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
# show the image
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (562, 762)

# %%
from keras.preprocessing.image import save_img
from keras.preprocessing.image import img_to_array

# convert image to a numpy array
img_array = img_to_array(img)
# save the image with a new filename
save_img('AF01HAS_numpy.jpg', img_array)
# load the image to confirm it was saved correctly
img = load_img('AF01HAS_numpy.jpg')
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (562, 762)

# %%
import os
import fnmatch
import shutil

#Initialize the number of images in class:
k = 0
afraid = r"[A-Z][A-Z][0-9][0-9]AF*.JPG"
happy = r"[A-Z][A-Z][0-9][0-9]HA*.JPG"
basedir = 'data/train/fearful/'
# List all files in the female directories with angry expressions using scandir()
for i in range(1,36):
    if i < 10:
        n = '0' + str(i)
    else:
        n = str(i)   
    basepath = 'KDEF/KDEF_and_AKDEF/KDEF/AF' + n + '/'
    with os.scandir(basepath) as entries:
        for entry in entries:
            if entry.is_file():
                if fnmatch.fnmatch(entry.name, afraid):
                    #print(entry.name)
                    # Separate base from extension
                    base, extension = os.path.splitext(entry.name)
                     # Initial new name
                    new_name = os.path.join(basedir,entry.name)
                    print(new_name)

                    # If folder basedir/base does not exist... You don't want to create it?
                    if not os.path.exists(os.path.join(basedir, base)):
                        print (os.path.join(basedir,base), "not found" )
                        continue    # Next filename
                    elif not os.path.exists(new_name):  # folder exists, file does not
                        shutil.copy(old_name, new_name)
                    else:  # folder exists, file exists as well
                        ii = 1
                        while True:
                            new_name = os.path.join(basedir,base, base + "_" + str(ii) + extension)
                            if os.path.exists(newname):
                                shutil.copy(old_name, new_name)
                                print ("Copied", old_name, "as", new_name)
                                break 
                            ii += 1
                    k += 1
                    
# List all files in the male directories with angry expressions using scandir()                    
for i in range(1,36):
    if i < 10:
        n = '0' + str(i)
    else:
        n = str(i)   
    basepath = 'KDEF/KDEF_and_AKDEF/KDEF/AM' + n + '/'
    with os.scandir(basepath) as entries:
        for entry in entries:
            if entry.is_file():
                if fnmatch.fnmatch(entry.name, afraid):
                    print(entry.name)
                    k += 1
print(k)
# Out:
# data/train/fearful/AF01AFHL.JPG
# data/train/fearful/AF01AFHL not found
# data/train/fearful/AF01AFFR.JPG
# data/train/fearful/AF01AFFR not found
# data/train/fearful/AF01AFHR.JPG
# data/train/fearful/AF01AFHR not found
# data/train/fearful/AF01AFS.JPG
# data/train/fearful/AF01AFS not found
# data/train/fearful/AF01AFFL.JPG
# data/train/fearful/AF01AFFL not found
# data/train/fearful/AF02AFS.JPG
# data/train/fearful/AF02AFS not found
# data/train/fearful/AF02AFFR.JPG
# data/train/fearful/AF02AFFR not found
# data/train/fearful/AF02AFHL.JPG
# data/train/fearful/AF02AFHL not found
# data/train/fearful/AF02AFFL.JPG
# data/train/fearful/AF02AFFL not found
# data/train/fearful/AF02AFHR.JPG
# data/train/fearful/AF02AFHR not found
# data/train/fearful/AF03AFHL.JPG
# data/train/fearful/AF03AFHL not found
# data/train/fearful/AF03AFFR.JPG
# data/train/fearful/AF03AFFR not found
# data/train/fearful/AF03AFHR.JPG
# data/train/fearful/AF03AFHR not found
# data/train/fearful/AF03AFFL.JPG
# data/train/fearful/AF03AFFL not found
# data/train/fearful/AF03AFS.JPG
# data/train/fearful/AF03AFS not found
# data/train/fearful/AF04AFFL.JPG
# data/train/fearful/AF04AFFL not found
# data/train/fearful/AF04AFS.JPG
# data/train/fearful/AF04AFS not found
# data/train/fearful/AF04AFHR.JPG
# data/train/fearful/AF04AFHR not found
# data/train/fearful/AF04AFFR.JPG
# data/train/fearful/AF04AFFR not found
# data/train/fearful/AF04AFHL.JPG
# data/train/fearful/AF04AFHL not found
# data/train/fearful/AF05AFHR.JPG
# data/train/fearful/AF05AFHR not found
# data/train/fearful/AF05AFFL.JPG
# data/train/fearful/AF05AFFL not found
# data/train/fearful/AF05AFS.JPG
# data/train/fearful/AF05AFS not found
# data/train/fearful/AF05AFHL.JPG
# data/train/fearful/AF05AFHL not found
# data/train/fearful/AF05AFFR.JPG
# data/train/fearful/AF05AFFR not found
# data/train/fearful/AF06AFS.JPG
# data/train/fearful/AF06AFS not found
# data/train/fearful/AF06AFFL.JPG
# data/train/fearful/AF06AFFL not found
# data/train/fearful/AF06AFHR.JPG
# data/train/fearful/AF06AFHR not found
# data/train/fearful/AF06AFFR.JPG
# data/train/fearful/AF06AFFR not found
# data/train/fearful/AF06AFHL.JPG
# data/train/fearful/AF06AFHL not found
# data/train/fearful/AF07AFHR.JPG
# data/train/fearful/AF07AFHR not found
# data/train/fearful/AF07AFFL.JPG
# data/train/fearful/AF07AFFL not found
# data/train/fearful/AF07AFHL.JPG
# data/train/fearful/AF07AFHL not found
# data/train/fearful/AF07AFFR.JPG
# data/train/fearful/AF07AFFR not found
# data/train/fearful/AF07AFS.JPG
# data/train/fearful/AF07AFS not found
# data/train/fearful/AF08AFS.JPG
# data/train/fearful/AF08AFS not found
# data/train/fearful/AF08AFFR.JPG
# data/train/fearful/AF08AFFR not found
# data/train/fearful/AF08AFHL.JPG
# data/train/fearful/AF08AFHL not found
# data/train/fearful/AF08AFFL.JPG
# data/train/fearful/AF08AFFL not found
# data/train/fearful/AF08AFHR.JPG
# data/train/fearful/AF08AFHR not found
# data/train/fearful/AF09AFHL.JPG
# data/train/fearful/AF09AFHL not found
# data/train/fearful/AF09AFFR.JPG
# data/train/fearful/AF09AFFR not found
# data/train/fearful/AF09AFS.JPG
# data/train/fearful/AF09AFS not found
# data/train/fearful/AF09AFHR.JPG
# data/train/fearful/AF09AFHR not found
# data/train/fearful/AF09AFFL.JPG
# data/train/fearful/AF09AFFL not found
# data/train/fearful/AF10AFFR.JPG
# data/train/fearful/AF10AFFR not found
# data/train/fearful/AF10AFHL.JPG
# data/train/fearful/AF10AFHL not found
# data/train/fearful/AF10AFS.JPG
# data/train/fearful/AF10AFS not found
# data/train/fearful/AF10AFFL.JPG
# data/train/fearful/AF10AFFL not found
# data/train/fearful/AF10AFHR.JPG
# data/train/fearful/AF10AFHR not found
# data/train/fearful/AF11AFHL.JPG
# data/train/fearful/AF11AFHL not found
# data/train/fearful/AF11AFFR.JPG
# data/train/fearful/AF11AFFR not found
# data/train/fearful/AF11AFS.JPG
# data/train/fearful/AF11AFS not found
# data/train/fearful/AF11AFHR.JPG
# data/train/fearful/AF11AFHR not found
# data/train/fearful/AF11AFFL.JPG
# data/train/fearful/AF11AFFL not found
# data/train/fearful/AF12AFFR.JPG
# data/train/fearful/AF12AFFR not found
# data/train/fearful/AF12AFHL.JPG
# data/train/fearful/AF12AFHL not found
# data/train/fearful/AF12AFS.JPG
# data/train/fearful/AF12AFS not found
# data/train/fearful/AF12AFFL.JPG
# data/train/fearful/AF12AFFL not found
# data/train/fearful/AF12AFHR.JPG
# data/train/fearful/AF12AFHR not found
# data/train/fearful/AF13AFHL.JPG
# data/train/fearful/AF13AFHL not found
# data/train/fearful/AF13AFFR.JPG
# data/train/fearful/AF13AFFR not found
# data/train/fearful/AF13AFHR.JPG
# data/train/fearful/AF13AFHR not found
# data/train/fearful/AF13AFFL.JPG
# data/train/fearful/AF13AFFL not found
# data/train/fearful/AF13AFS.JPG
# data/train/fearful/AF13AFS not found
# data/train/fearful/AF14AFFL.JPG
# data/train/fearful/AF14AFFL not found
# data/train/fearful/AF14AFHR.JPG
# data/train/fearful/AF14AFHR not found
# data/train/fearful/AF14AFS.JPG
# data/train/fearful/AF14AFS not found
# data/train/fearful/AF14AFFR.JPG
# data/train/fearful/AF14AFFR not found
# data/train/fearful/AF14AFHL.JPG
# data/train/fearful/AF14AFHL not found
# data/train/fearful/AF15AFHR.JPG
# data/train/fearful/AF15AFHR not found
# data/train/fearful/AF15AFFL.JPG
# data/train/fearful/AF15AFFL not found
# data/train/fearful/AF15AFS.JPG
# data/train/fearful/AF15AFS not found
# data/train/fearful/AF15AFHL.JPG
# data/train/fearful/AF15AFHL not found
# data/train/fearful/AF15AFFR.JPG
# data/train/fearful/AF15AFFR not found
# data/train/fearful/AF16AFS.JPG
# data/train/fearful/AF16AFS not found
# data/train/fearful/AF16AFFL.JPG
# data/train/fearful/AF16AFFL not found
# data/train/fearful/AF16AFHR.JPG
# data/train/fearful/AF16AFHR not found
# data/train/fearful/AF16AFFR.JPG
# data/train/fearful/AF16AFFR not found
# data/train/fearful/AF16AFHL.JPG
# data/train/fearful/AF16AFHL not found
# data/train/fearful/AF17AFHR.JPG
# data/train/fearful/AF17AFHR not found
# data/train/fearful/AF17AFFL.JPG
# data/train/fearful/AF17AFFL not found
# data/train/fearful/AF17AFHL.JPG
# data/train/fearful/AF17AFHL not found
# data/train/fearful/AF17AFS.JPG
# data/train/fearful/AF17AFS not found
# data/train/fearful/AF17AFFR.JPG
# data/train/fearful/AF17AFFR not found
# data/train/fearful/AF18AFS.JPG
# data/train/fearful/AF18AFS not found
# data/train/fearful/AF18AFFR.JPG
# data/train/fearful/AF18AFFR not found
# data/train/fearful/AF18AFHL.JPG
# data/train/fearful/AF18AFHL not found
# data/train/fearful/AF18AFFL.JPG
# data/train/fearful/AF18AFFL not found
# data/train/fearful/AF18AFHR.JPG
# data/train/fearful/AF18AFHR not found
# data/train/fearful/AF19AFHL.JPG
# data/train/fearful/AF19AFHL not found
# data/train/fearful/AF19AFFR.JPG
# data/train/fearful/AF19AFFR not found
# data/train/fearful/AF19AFS.JPG
# data/train/fearful/AF19AFS not found
# data/train/fearful/AF19AFHR.JPG
# data/train/fearful/AF19AFHR not found
# data/train/fearful/AF19AFFL.JPG
# data/train/fearful/AF19AFFL not found
# data/train/fearful/AF20AFS.JPG
# data/train/fearful/AF20AFS not found
# data/train/fearful/AF20AFHR.JPG
# data/train/fearful/AF20AFHR not found
# data/train/fearful/AF20AFFL.JPG
# data/train/fearful/AF20AFFL not found
# data/train/fearful/AF20AFHL.JPG
# data/train/fearful/AF20AFHL not found
# data/train/fearful/AF20AFFR.JPG
# data/train/fearful/AF20AFFR not found
# data/train/fearful/AF21AFFL.JPG
# data/train/fearful/AF21AFFL not found
# data/train/fearful/AF21AFHR.JPG
# data/train/fearful/AF21AFHR not found
# data/train/fearful/AF21AFS.JPG
# data/train/fearful/AF21AFS not found
# data/train/fearful/AF21AFFR.JPG
# data/train/fearful/AF21AFFR not found
# data/train/fearful/AF21AFHL.JPG
# data/train/fearful/AF21AFHL not found
# data/train/fearful/AF22AFHR.JPG
# data/train/fearful/AF22AFHR not found
# data/train/fearful/AF22AFFL.JPG
# data/train/fearful/AF22AFFL not found
# data/train/fearful/AF22AFS.JPG
# data/train/fearful/AF22AFS not found
# data/train/fearful/AF22AFHL.JPG
# data/train/fearful/AF22AFHL not found
# data/train/fearful/AF22AFFR.JPG
# data/train/fearful/AF22AFFR not found
# data/train/fearful/AF23AFFL.JPG
# data/train/fearful/AF23AFFL not found
# data/train/fearful/AF23AFHR.JPG
# data/train/fearful/AF23AFHR not found
# data/train/fearful/AF23AFS.JPG
# data/train/fearful/AF23AFS not found
# data/train/fearful/AF23AFFR.JPG
# data/train/fearful/AF23AFFR not found
# data/train/fearful/AF23AFHL.JPG
# data/train/fearful/AF23AFHL not found
# data/train/fearful/AF24AFHL.JPG
# data/train/fearful/AF24AFHL not found
# data/train/fearful/AF24AFS.JPG
# data/train/fearful/AF24AFS not found
# data/train/fearful/AF24AFFR.JPG
# data/train/fearful/AF24AFFR not found
# data/train/fearful/AF24AFHR.JPG
# data/train/fearful/AF24AFHR not found
# data/train/fearful/AF24AFFL.JPG
# data/train/fearful/AF24AFFL not found
# data/train/fearful/AF25AFFR.JPG
# data/train/fearful/AF25AFFR not found
# data/train/fearful/AF25AFHL.JPG
# data/train/fearful/AF25AFHL not found
# data/train/fearful/AF25AFFL.JPG
# data/train/fearful/AF25AFFL not found
# data/train/fearful/AF25AFHR.JPG
# data/train/fearful/AF25AFHR not found
# data/train/fearful/AF25AFS.JPG
# data/train/fearful/AF25AFS not found
# data/train/fearful/AF26AFHL.JPG
# data/train/fearful/AF26AFHL not found
# data/train/fearful/AF26AFFR.JPG
# data/train/fearful/AF26AFFR not found
# data/train/fearful/AF26AFS.JPG
# data/train/fearful/AF26AFS not found
# data/train/fearful/AF26AFHR.JPG
# data/train/fearful/AF26AFHR not found
# data/train/fearful/AF26AFFL.JPG
# data/train/fearful/AF26AFFL not found
# data/train/fearful/AF27AFFR.JPG
# data/train/fearful/AF27AFFR not found
# data/train/fearful/AF27AFHL.JPG
# data/train/fearful/AF27AFHL not found
# data/train/fearful/AF27AFS.JPG
# data/train/fearful/AF27AFS not found
# data/train/fearful/AF27AFFL.JPG
# data/train/fearful/AF27AFFL not found
# data/train/fearful/AF27AFHR.JPG
# data/train/fearful/AF27AFHR not found
# data/train/fearful/AF28AFHR.JPG
# data/train/fearful/AF28AFHR not found
# data/train/fearful/AF28AFFL.JPG
# data/train/fearful/AF28AFFL not found
# data/train/fearful/AF28AFS.JPG
# data/train/fearful/AF28AFS not found
# data/train/fearful/AF28AFHL.JPG
# data/train/fearful/AF28AFHL not found
# data/train/fearful/AF28AFFR.JPG
# data/train/fearful/AF28AFFR not found
# data/train/fearful/AF29AFFL.JPG
# data/train/fearful/AF29AFFL not found
# data/train/fearful/AF29AFHR.JPG
# data/train/fearful/AF29AFHR not found
# data/train/fearful/AF29AFFR.JPG
# data/train/fearful/AF29AFFR not found
# data/train/fearful/AF29AFHL.JPG
# data/train/fearful/AF29AFHL not found
# data/train/fearful/AF29AFS.JPG
# data/train/fearful/AF29AFS not found
# data/train/fearful/AF30AFS.JPG
# data/train/fearful/AF30AFS not found
# data/train/fearful/AF30AFHR.JPG
# data/train/fearful/AF30AFHR not found
# data/train/fearful/AF30AFFL.JPG
# data/train/fearful/AF30AFFL not found
# data/train/fearful/AF30AFHL.JPG
# data/train/fearful/AF30AFHL not found
# data/train/fearful/AF30AFFR.JPG
# data/train/fearful/AF30AFFR not found
# data/train/fearful/AF31AFFL.JPG
# data/train/fearful/AF31AFFL not found
# data/train/fearful/AF31AFHR.JPG
# data/train/fearful/AF31AFHR not found
# data/train/fearful/AF31AFFR.JPG
# data/train/fearful/AF31AFFR not found
# data/train/fearful/AF31AFHL.JPG
# data/train/fearful/AF31AFHL not found
# data/train/fearful/AF31AFS.JPG
# data/train/fearful/AF31AFS not found
# data/train/fearful/AF32AFHR.JPG
# data/train/fearful/AF32AFHR not found
# data/train/fearful/AF32AFFL.JPG
# data/train/fearful/AF32AFFL not found
# data/train/fearful/AF32AFS.JPG
# data/train/fearful/AF32AFS not found
# data/train/fearful/AF32AFHL.JPG
# data/train/fearful/AF32AFHL not found
# data/train/fearful/AF32AFFR.JPG
# data/train/fearful/AF32AFFR not found
# data/train/fearful/AF33AFFL.JPG
# data/train/fearful/AF33AFFL not found
# data/train/fearful/AF33AFHR.JPG
# data/train/fearful/AF33AFHR not found
# data/train/fearful/AF33AFS.JPG
# data/train/fearful/AF33AFS not found
# data/train/fearful/AF33AFFR.JPG
# data/train/fearful/AF33AFFR not found
# data/train/fearful/AF33AFHL.JPG
# data/train/fearful/AF33AFHL not found
# data/train/fearful/AF34AFS.JPG
# data/train/fearful/AF34AFS not found
# data/train/fearful/AF34AFHL.JPG
# data/train/fearful/AF34AFHL not found
# data/train/fearful/AF34AFFR.JPG
# data/train/fearful/AF34AFFR not found
# data/train/fearful/AF34AFHR.JPG
# data/train/fearful/AF34AFHR not found
# data/train/fearful/AF34AFFL.JPG
# data/train/fearful/AF34AFFL not found
# data/train/fearful/AF35AFFR.JPG
# data/train/fearful/AF35AFFR not found
# data/train/fearful/AF35AFHL.JPG
# data/train/fearful/AF35AFHL not found
# data/train/fearful/AF35AFFL.JPG
# data/train/fearful/AF35AFFL not found
# data/train/fearful/AF35AFHR.JPG
# data/train/fearful/AF35AFHR not found
# data/train/fearful/AF35AFS.JPG
# data/train/fearful/AF35AFS not found
# AM01AFFR.JPG
# AM01AFHL.JPG
# AM01AFFL.JPG
# AM01AFHR.JPG
# AM01AFS.JPG
# AM02AFHL.JPG
# AM02AFFR.JPG
# AM02AFS.JPG
# AM02AFHR.JPG
# AM02AFFL.JPG
# AM03AFFR.JPG
# AM03AFHL.JPG
# AM03AFFL.JPG
# AM03AFHR.JPG
# AM03AFS.JPG
# AM04AFS.JPG
# AM04AFHR.JPG
# AM04AFFL.JPG
# AM04AFHL.JPG
# AM04AFFR.JPG
# AM05AFFL.JPG
# AM05AFHR.JPG
# AM05AFS.JPG
# AM05AFFR.JPG
# AM05AFHL.JPG
# AM06AFS.JPG
# AM06AFHR.JPG
# AM06AFFL.JPG
# AM06AFHL.JPG
# AM06AFFR.JPG
# AM07AFFL.JPG
# AM07AFHR.JPG
# AM07AFFR.JPG
# AM07AFS.JPG
# AM07AFHL.JPG
# AM08AFS.JPG
# AM08AFHL.JPG
# AM08AFFR.JPG
# AM08AFHR.JPG
# AM08AFFL.JPG
# AM09AFFR.JPG
# AM09AFHL.JPG
# AM09AFS.JPG
# AM09AFFL.JPG
# AM09AFHR.JPG
# AM10AFHL.JPG
# AM10AFFR.JPG
# AM10AFS.JPG
# AM10AFHR.JPG
# AM10AFFL.JPG
# AM11AFFR.JPG
# AM11AFHL.JPG
# AM11AFS.JPG
# AM11AFFL.JPG
# AM11AFHR.JPG
# AM12AFHL.JPG
# AM12AFFR.JPG
# AM12AFS.JPG
# AM12AFHR.JPG
# AM12AFFL.JPG
# AM13AFFR.JPG
# AM13AFHL.JPG
# AM13AFFL.JPG
# AM13AFHR.JPG
# AM13AFS.JPG
# AM14AFHR.JPG
# AM14AFS.JPG
# AM14AFFL.JPG
# AM14AFHL.JPG
# AM14AFFR.JPG
# AM15AFFL.JPG
# AM15AFHR.JPG
# AM15AFS.JPG
# AM15AFFR.JPG
# AM15AFHL.JPG
# AM16AFS.JPG
# AM16AFHR.JPG
# AM16AFFL.JPG
# AM16AFHL.JPG
# AM16AFFR.JPG
# AM17AFFL.JPG
# AM17AFHR.JPG
# AM17AFS.JPG
# AM17AFFR.JPG
# AM17AFHL.JPG
# AM18AFHL.JPG
# AM18AFFR.JPG
# AM18AFS.JPG
# AM18AFHR.JPG
# AM18AFFL.JPG
# AM19AFFR.JPG
# AM19AFHL.JPG
# AM19AFS.JPG
# AM19AFFL.JPG
# AM19AFHR.JPG
# AM20AFS.JPG
# AM20AFFL.JPG
# AM20AFHR.JPG
# AM20AFFR.JPG
# AM20AFHL.JPG
# AM21AFHR.JPG
# AM21AFFL.JPG
# AM21AFS.JPG
# AM21AFHL.JPG
# AM21AFFR.JPG
# AM22AFFL.JPG
# AM22AFS.JPG
# AM22AFHR.JPG
# AM22AFFR.JPG
# AM22AFHL.JPG
# AM23AFHR.JPG
# AM23AFFL.JPG
# AM23AFS.JPG
# AM23AFHL.JPG
# AM23AFFR.JPG
# AM24AFFR.JPG
# AM24AFHL.JPG
# AM24AFS.JPG
# AM24AFFL.JPG
# AM24AFHR.JPG
# AM25AFHL.JPG
# AM25AFFR.JPG
# AM25AFHR.JPG
# AM25AFFL.JPG
# AM25AFS.JPG
# AM26AFFR.JPG
# AM26AFHL.JPG
# AM26AFS.JPG
# AM26AFFL.JPG
# AM26AFHR.JPG
# AM27AFHL.JPG
# AM27AFFR.JPG
# AM27AFHR.JPG
# AM27AFS.JPG
# AM27AFFL.JPG
# AM28AFFL.JPG
# AM28AFS.JPG
# AM28AFHR.JPG
# AM28AFFR.JPG
# AM28AFHL.JPG
# AM29AFHR.JPG
# AM29AFFL.JPG
# AM29AFHL.JPG
# AM29AFFR.JPG
# AM29AFS.JPG
# AM30AFS.JPG
# AM30AFFL.JPG
# AM30AFHR.JPG
# AM30AFFR.JPG
# AM30AFHL.JPG
# AM31AFHR.JPG
# AM31AFFL.JPG
# AM31AFS.JPG
# AM31AFHL.JPG
# AM31AFFR.JPG
# AM32AFS.JPG
# AM32AFFL.JPG
# AM32AFHR.JPG
# AM32AFFR.JPG
# AM32AFHL.JPG
# AM33AFHR.JPG
# AM33AFFL.JPG
# AM33AFS.JPG
# AM33AFHL.JPG
# AM33AFFR.JPG
# AM34AFFR.JPG
# AM34AFS.JPG
# AM34AFHL.JPG
# AM34AFFL.JPG
# AM34AFHR.JPG
# AM35AFHL.JPG
# AM35AFFR.JPG
# AM35AFHR.JPG
# AM35AFFL.JPG
# AM35AFS.JPG
# 175

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#define a sequential API model in keras
model = tf.keras.Sequential()

# %%
#define first hidden layer
model.add(tf.keras.layers.Dense(32, activation='relu', input_shape = (562*762, )))

# %%
#define second hidden layer
model.add(tf.keras.layers.Dense(16,activation='relu'))

# %%
#define output layer
model.add(tf.keras.layers.Dense(7, activation='softmax'))

# %%
#Compile the model
model.compile('adam', loss='categorical_crossentropy')
