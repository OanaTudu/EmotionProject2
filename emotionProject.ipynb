# %% [markdown]
# ## Emotion Recognition Project
#
# 2019 - OT.
#
# Given the Karolinska faces collection, train a classifier to predict emotion.
# Details about the data (KDEF):
# 70 subjects (35 male, 35 female), all white, between 20 and 30 years of age, photographed with 7 emotion expressions:
# neutral, happy, angry, afraid, disgusted, sad, surprised
#
# Files stored in KDEF folder. Image naming code:
# Codes:
# 	Example: AF01ANFL.JPG
# 		Letter 1: Session
# 					A = series one
# 					B = series two
# 		Letter 2: Gender
# 					F = female
# 					M = male
# 		Letter 3 & 4: Identity number
# 					01 - 35
# 		Letter 5 & 6: Expression
# 					AF = afraid
# 					AN = angry
# 					DI = disgusted
# 					HA = happy
# 					NE = neutral
# 					SA = sad
# 					SU = surprised
# 		Letter 7 & 8: Angle
# 					FL = full left profile
# 					HL = half left profile
# 					S = straight
# 					HR = half right profile
# 					FR = full right profile

# %%
from keras.preprocessing.image import load_img
# load the image
img = load_img('AF01HAS.jpg')
# report details about the image
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
# show the image
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (562, 762)

# %%
from keras.preprocessing.image import save_img
from keras.preprocessing.image import img_to_array

# convert image to a numpy array
img_array = img_to_array(img)
# save the image with a new filename
save_img('AF01HAS_numpy.jpg', img_array)
# load the image to confirm it was saved correctly
img = load_img('AF01HAS_numpy.jpg')
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (562, 762)

# %%
import os
import fnmatch
import shutil

#Initialize the number of images in class:
k = 0
afraid = r"[A-Z][A-Z][0-9][0-9]AF*.JPG"
happy = r"[A-Z][A-Z][0-9][0-9]HA*.JPG"
basedir = 'data/train/fearful/'
# List all files in the female directories with angry expressions using scandir()
for i in range(1,36):
    if i < 10:
        n = '0' + str(i)
    else:
        n = str(i)   
    basepath = 'KDEF/KDEF_and_AKDEF/KDEF/AF' + n + '/'
    with os.scandir(basepath) as entries:
        for entry in entries:
            if entry.is_file():
                if fnmatch.fnmatch(entry.name, afraid):
                    print(entry.name)
                    old_name = os.path.join(basepath, entry.name)
                    print(old_name)
                     # Initial new name
                    new_name = os.path.join(basedir,entry.name)
                    print(new_name)
                    shutil.copy(old_name, new_name)
                    
                    k += 1
                    
# List all files in the male directories with angry expressions using scandir()                    
for i in range(1,36):
    if i < 10:
        n = '0' + str(i)
    else:
        n = str(i)   
    basepath = 'KDEF/KDEF_and_AKDEF/KDEF/AM' + n + '/'
    with os.scandir(basepath) as entries:
        for entry in entries:
            if entry.is_file():
                if fnmatch.fnmatch(entry.name, afraid):
                    print(entry.name)
                    old_name = os.path.join(basepath, entry.name)
                    print(old_name)
                     # Initial new name
                    new_name = os.path.join(basedir,entry.name)
                    print(new_name)
                    shutil.copy(old_name, new_name)
                    k += 1
print(k)
# Out:
# AF01AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/A
FHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM01/AM01AFHR.JPG
# data/train/fearful/AM01AFHR.JPG
# AM01AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM01/AM01AFS.JPG
# data/train/fearful/AM01AFS.JPG
# AM02AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM02/AM02AFHL.JPG
# data/train/fearful/AM02AFHL.JPG
# AM02AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM02/AM02AFFR.JPG
# data/train/fearful/AM02AFFR.JPG
# AM02AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM02/AM02AFS.JPG
# data/train/fearful/AM02AFS.JPG
# AM02AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM02/AM02AFHR.JPG
# data/train/fearful/AM02AFHR.JPG
# AM02AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM02/AM02AFFL.JPG
# data/train/fearful/AM02AFFL.JPG
# AM03AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM03/AM03AFFR.JPG
# data/train/fearful/AM03AFFR.JPG
# AM03AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM03/AM03AFHL.JPG
# data/train/fearful/AM03AFHL.JPG
# AM03AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM03/AM03AFFL.JPG
# data/train/fearful/AM03AFFL.JPG
# AM03AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM03/AM03AFHR.JPG
# data/train/fearful/AM03AFHR.JPG
# AM03AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM03/AM03AFS.JPG
# data/train/fearful/AM03AFS.JPG
# AM04AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM04/AM04AFS.JPG
# data/train/fearful/AM04AFS.JPG
# AM04AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM04/AM04AFHR.JPG
# data/train/fearful/AM04AFHR.JPG
# AM04AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM04/AM04AFFL.JPG
# data/train/fearful/AM04AFFL.JPG
# AM04AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM04/AM04AFHL.JPG
# data/train/fearful/AM04AFHL.JPG
# AM04AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM04/AM04AFFR.JPG
# data/train/fearful/AM04AFFR.JPG
# AM05AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM05/AM05AFFL.JPG
# data/train/fearful/AM05AFFL.JPG
# AM05AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM05/AM05AFHR.JPG
# data/train/fearful/AM05AFHR.JPG
# AM05AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM05/AM05AFS.JPG
# data/train/fearful/AM05AFS.JPG
# AM05AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM05/AM05AFFR.JPG
# data/train/fearful/AM05AFFR.JPG
# AM05AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM05/AM05AFHL.JPG
# data/train/fearful/AM05AFHL.JPG
# AM06AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM06/AM06AFS.JPG
# data/train/fearful/AM06AFS.JPG
# AM06AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM06/AM06AFHR.JPG
# data/train/fearful/AM06AFHR.JPG
# AM06AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM06/AM06AFFL.JPG
# data/train/fearful/AM06AFFL.JPG
# AM06AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM06/AM06AFHL.JPG
# data/train/fearful/AM06AFHL.JPG
# AM06AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM06/AM06AFFR.JPG
# data/train/fearful/AM06AFFR.JPG
# AM07AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM07/AM07AFFL.JPG
# data/train/fearful/AM07AFFL.JPG
# AM07AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM07/AM07AFHR.JPG
# data/train/fearful/AM07AFHR.JPG
# AM07AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM07/AM07AFFR.JPG
# data/train/fearful/AM07AFFR.JPG
# AM07AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM07/AM07AFS.JPG
# data/train/fearful/AM07AFS.JPG
# AM07AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM07/AM07AFHL.JPG
# data/train/fearful/AM07AFHL.JPG
# AM08AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM08/AM08AFS.JPG
# data/train/fearful/AM08AFS.JPG
# AM08AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM08/AM08AFHL.JPG
# data/train/fearful/AM08AFHL.JPG
# AM08AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM08/AM08AFFR.JPG
# data/train/fearful/AM08AFFR.JPG
# AM08AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/A
FS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM30/AM30AFS.JPG
# data/train/fearful/AM30AFS.JPG
# AM30AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM30/AM30AFFL.JPG
# data/train/fearful/AM30AFFL.JPG
# AM30AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM30/AM30AFHR.JPG
# data/train/fearful/AM30AFHR.JPG
# AM30AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM30/AM30AFFR.JPG
# data/train/fearful/AM30AFFR.JPG
# AM30AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM30/AM30AFHL.JPG
# data/train/fearful/AM30AFHL.JPG
# AM31AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM31/AM31AFHR.JPG
# data/train/fearful/AM31AFHR.JPG
# AM31AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM31/AM31AFFL.JPG
# data/train/fearful/AM31AFFL.JPG
# AM31AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM31/AM31AFS.JPG
# data/train/fearful/AM31AFS.JPG
# AM31AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM31/AM31AFHL.JPG
# data/train/fearful/AM31AFHL.JPG
# AM31AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM31/AM31AFFR.JPG
# data/train/fearful/AM31AFFR.JPG
# AM32AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM32/AM32AFS.JPG
# data/train/fearful/AM32AFS.JPG
# AM32AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM32/AM32AFFL.JPG
# data/train/fearful/AM32AFFL.JPG
# AM32AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM32/AM32AFHR.JPG
# data/train/fearful/AM32AFHR.JPG
# AM32AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM32/AM32AFFR.JPG
# data/train/fearful/AM32AFFR.JPG
# AM32AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM32/AM32AFHL.JPG
# data/train/fearful/AM32AFHL.JPG
# AM33AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM33/AM33AFHR.JPG
# data/train/fearful/AM33AFHR.JPG
# AM33AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM33/AM33AFFL.JPG
# data/train/fearful/AM33AFFL.JPG
# AM33AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM33/AM33AFS.JPG
# data/train/fearful/AM33AFS.JPG
# AM33AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM33/AM33AFHL.JPG
# data/train/fearful/AM33AFHL.JPG
# AM33AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM33/AM33AFFR.JPG
# data/train/fearful/AM33AFFR.JPG
# AM34AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM34/AM34AFFR.JPG
# data/train/fearful/AM34AFFR.JPG
# AM34AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM34/AM34AFS.JPG
# data/train/fearful/AM34AFS.JPG
# AM34AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM34/AM34AFHL.JPG
# data/train/fearful/AM34AFHL.JPG
# AM34AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM34/AM34AFFL.JPG
# data/train/fearful/AM34AFFL.JPG
# AM34AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM34/AM34AFHR.JPG
# data/train/fearful/AM34AFHR.JPG
# AM35AFHL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM35/AM35AFHL.JPG
# data/train/fearful/AM35AFHL.JPG
# AM35AFFR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM35/AM35AFFR.JPG
# data/train/fearful/AM35AFFR.JPG
# AM35AFHR.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM35/AM35AFHR.JPG
# data/train/fearful/AM35AFHR.JPG
# AM35AFFL.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM35/AM35AFFL.JPG
# data/train/fearful/AM35AFFL.JPG
# AM35AFS.JPG
# KDEF/KDEF_and_AKDEF/KDEF/AM35/AM35AFS.JPG
# data/train/fearful/AM35AFS.JPG
# 350

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#define a sequential API model in keras
model = tf.keras.Sequential()

# %%
#define first hidden layer
model.add(tf.keras.layers.Dense(32, activation='relu', input_shape = (562*762, )))

# %%
#define second hidden layer
model.add(tf.keras.layers.Dense(16,activation='relu'))

# %%
#define output layer
model.add(tf.keras.layers.Dense(7, activation='softmax'))

# %%
#Compile the model
model.compile('adam', loss='categorical_crossentropy')
